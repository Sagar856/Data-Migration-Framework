# %%
# %sql
CREATE OR REPLACE VIEW workspace.reporting.vw_dim_product AS
SELECT
    ProductKey,
    ProductId,
    ProductName,
    ProductCategory,
    ProductPrice
FROM workspace.gold.dim_product
-- WHERE IsCurrent = true;
