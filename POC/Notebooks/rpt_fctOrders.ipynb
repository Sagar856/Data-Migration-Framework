# %%
# %sql
CREATE OR REPLACE VIEW workspace.reporting.vw_fact_orders AS
SELECT
    OrderKey,
    OrderId,
    CustomerKey,
    ProductKey,
    OrderDateKey,
    OrderPrice
FROM workspace.gold.fact_orders;
