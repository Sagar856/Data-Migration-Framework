# %%
# %sql
CREATE OR REPLACE VIEW workspace.reporting.vw_dim_customer AS
SELECT
    CustomerKey,
    CustomerId,
    CustomerName,
    Age,
    Gender,
    City
FROM workspace.gold.dim_customer
-- WHERE IsCurrent = true;
