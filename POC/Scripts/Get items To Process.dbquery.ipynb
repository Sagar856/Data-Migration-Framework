-- %%
WITH result as (
select
  TableName,
  ProcessInstanceId,
  ProcessQueueId,
  StageId
from
  control.processqueue
where
  ProcessStatus = 'AwaitingProcessing'
  and QueuedTime is null
)

select * from result;
